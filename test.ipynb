# %%
import pandas as pd

dataset = pd.read_csv('RKI_COVID19.csv', parse_dates=['Meldedatum'], usecols=["Bundesland","Geschlecht", "AnzahlFall","AnzahlTodesfall","Meldedatum"], index_col=0)
dataset.groupby("Bundesland").mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='Bundesland'>

# %%
dataset.groupby("Meldedatum").AnzahlFall.sum().plot(kind="density", figsize=(15,7))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
dataset.iloc[1]
# Out:
# ObjectId                                     2
# IdBundesland                                 1
# Bundesland                  Schleswig-Holstein
# Landkreis                         SK Flensburg
# Altersgruppe                           A00-A04
# Geschlecht                                   M
# AnzahlFall                                   1
# AnzahlTodesfall                              0
# Meldedatum              2020/10/29 00:00:00+00
# IdLandkreis                               1001
# Datenstand               14.04.2021, 00:00 Uhr
# NeuerFall                                    0
# NeuerTodesfall                              -9
# Refdatum                2020/10/29 00:00:00+00
# NeuGenesen                                   0
# AnzahlGenesen                                1
# IstErkrankungsbeginn                         0
# Altersgruppe2                Nicht übermittelt
# Name: 1, dtype: object

# %%
dataset.iloc[1::]
# Out:
#          ObjectId  IdBundesland          Bundesland            Landkreis  \
# 1               2             1  Schleswig-Holstein         SK Flensburg
# 2               3             1  Schleswig-Holstein         SK Flensburg
# 3               4             1  Schleswig-Holstein         SK Flensburg
# 4               5             1  Schleswig-Holstein         SK Flensburg
# 5               6             1  Schleswig-Holstein         SK Flensburg
# ...           ...           ...                 ...                  ...
# 1652690   1652691            16           Thüringen  LK Altenburger Land
# 1652691   1652692            16           Thüringen  LK Altenburger Land
# 1652692   1652693            16           Thüringen  LK Altenburger Land
# 1652693   1652694            16           Thüringen  LK Altenburger Land
# 1652694   1652695            16           Thüringen  LK Altenburger Land
#
#         Altersgruppe Geschlecht  AnzahlFall  AnzahlTodesfall  \
# ...

# %%
dataset.iloc[1,3]
# Out:
# 'SK Flensburg'

# %%
dataset[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-1ec12ad25fa7> in <module>
# ----> 1 dataset[1]
#
# ...

# %%
dataset.describe()
# Out:
#            ObjectId  IdBundesland    AnzahlFall  AnzahlTodesfall  \
# count  1.652695e+06  1.652695e+06  1.652695e+06     1.652695e+06
# mean   8.263480e+05  7.967252e+00  1.841631e+00     4.785275e-02
# std    4.770921e+05  3.664537e+00  2.647663e+00     2.777634e-01
# min    1.000000e+00  1.000000e+00 -3.000000e+00    -1.000000e+00
# 25%    4.131745e+05  5.000000e+00  1.000000e+00     0.000000e+00
# 50%    8.263480e+05  8.000000e+00  1.000000e+00     0.000000e+00
# 75%    1.239522e+06  9.000000e+00  2.000000e+00     0.000000e+00
# max    1.652695e+06  1.600000e+01  1.450000e+02     1.900000e+01
#
#         IdLandkreis     NeuerFall  NeuerTodesfall    NeuGenesen  \
# count  1.652695e+06  1.652695e+06    1.652695e+06  1.652695e+06
# mean   8.293046e+03  5.001528e-03   -8.645914e+00 -9.041178e-01
# std    3.627689e+03  7.345220e-02    1.750274e+00  2.716399e+00
# min    1.001000e+03 -1.000000e+00   -9.000000e+00 -9.000000e+00
# ...

# %%
dataset.shape
# Out:
# (1652695, 18)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1652695 entries, 0 to 1652694
# Data columns (total 18 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   ObjectId              1652695 non-null  int64
#  1   IdBundesland          1652695 non-null  int64
#  2   Bundesland            1652695 non-null  object
#  3   Landkreis             1652695 non-null  object
#  4   Altersgruppe          1652695 non-null  object
#  5   Geschlecht            1652695 non-null  object
#  6   AnzahlFall            1652695 non-null  int64
#  7   AnzahlTodesfall       1652695 non-null  int64
#  8   Meldedatum            1652695 non-null  datetime64[ns, UTC]
#  9   IdLandkreis           1652695 non-null  int64
#  10  Datenstand            1652695 non-null  object
#  11  NeuerFall             1652695 non-null  int64
#  12  NeuerTodesfall        1652695 non-null  int64
#  13  Refdatum              1652695 non-null  object
# ...

# %%
df = (dataset["Geschlecht"] == "M")

# %%
df
# Out:
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 1652690    False
# 1652691    False
# 1652692    False
# 1652693    False
# 1652694    False
# Name: Geschlecht, Length: 1652695, dtype: bool

# %%
dataset.groupby("Geschlecht").sum()
# Out:
#                 ObjectId  IdBundesland  AnzahlFall  AnzahlTodesfall  \
# Geschlecht
# M           653217648629       6307905     1447134            40820
# W           698958640210       6735509     1575502            38068
# unbekannt    13524919021        124024       21019              198
#
#             IdLandkreis  NeuerFall  NeuerTodesfall  NeuGenesen  AnzahlGenesen  \
# Geschlecht
# M            6567602107       4040        -6848296     -763488        1282009
# W            7008640549       4061        -7294108     -713797        1417700
# unbekannt     129633083        165         -146655      -16946          18628
#
#             IstErkrankungsbeginn
# Geschlecht
# M                         546531
# W                         591360
# unbekannt                   6183

# %%
ds=pd.pivot_table(dataset, values="AnzahlFall", index=["Bundesland"], columns=["Geschlecht"])
ds.plot.bar(figsize=(16,8))
ds
# Out:
# Geschlecht                     M         W  unbekannt
# Bundesland
# Baden-Württemberg       1.701649  1.729453   1.423330
# Bayern                  1.800361  1.792505   1.277367
# Berlin                  1.867755  1.927240   1.303619
# Brandenburg             1.481929  1.607034   1.074380
# Bremen                  2.211626  2.182413   1.200000
# Hamburg                 2.889039  3.021336   1.121780
# Hessen                  1.851748  1.892191   1.245592
# Mecklenburg-Vorpommern  1.485405  1.572361   1.345324
# Niedersachsen           1.647543  1.657284   1.188708
# Nordrhein-Westfalen     1.991223  2.032225   1.316162
# Rheinland-Pfalz         1.607115  1.658300   1.274775
# Saarland                1.786673  1.882804   1.092593
# Sachsen                 2.308629  2.663057   1.636364
# Sachsen-Anhalt          1.751040  1.874667   1.185771
# Schleswig-Holstein      1.366572  1.392913   1.185185
# Thüringen               1.489650  1.605808   1.131868

# %%
dataset = dataset.where(dataset.index.Bundesland == "Bayern")
df= dataset.groupby(["Bundesland", "Geschlecht"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-628b4f4127d4> in <module>
# ----> 1 dataset = dataset.where(dataset.index.Bundesland == "Bayern")
#       2 df= dataset.groupby(["Bundesland", "Geschlecht"])
#
# AttributeError: 'DatetimeIndex' object has no attribute 'Bundesland'

# %%
df.sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='Bundesland,Geschlecht'>

# %%
df.apply(lambda x: x.describe()).head(20)
# Out:
#                                          ObjectId  IdBundesland  \
# Bundesland        Geschlecht
# Baden-Württemberg M          count  111872.000000      111872.0
#                              mean   846763.091623           8.0
#                              std     66222.868121           0.0
#                              min    732501.000000           8.0
#                              25%    789474.750000           8.0
#                              50%    845829.500000           8.0
#                              75%    903688.250000           8.0
#                              max    961441.000000           8.0
#                   W          count  116004.000000      116004.0
#                              mean   848097.915055           8.0
#                              std     65994.487176           0.0
#                              min    732602.000000           8.0
#                              25%    790929.750000           8.0
# ...

# %%
dataset.where(dataset.AnzahlFall==0)
# Out:
#                           Geschlecht  AnzahlFall  AnzahlTodesfall
# Meldedatum
# 2020-09-30 00:00:00+00:00        NaN         NaN              NaN
# 2020-10-29 00:00:00+00:00        NaN         NaN              NaN
# 2020-11-03 00:00:00+00:00        NaN         NaN              NaN
# 2020-11-20 00:00:00+00:00        NaN         NaN              NaN
# 2020-11-23 00:00:00+00:00        NaN         NaN              NaN
# ...                              ...         ...              ...
# 2021-04-07 00:00:00+00:00        NaN         NaN              NaN
# 2021-04-08 00:00:00+00:00        NaN         NaN              NaN
# 2021-04-09 00:00:00+00:00        NaN         NaN              NaN
# 2021-04-11 00:00:00+00:00        NaN         NaN              NaN
# 2021-04-06 00:00:00+00:00        NaN         NaN              NaN
#
# [1652695 rows x 3 columns]

# %%
df.apply(lambda x: x.describe()).head(20)
# Out:
# <ipython-input-30-12c91d62c205>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.apply(lambda x: x.describe()).head(20)
#             ObjectId  IdBundesland Bundesland   Landkreis Altersgruppe  \
# 25%     1.036963e+06           9.0        NaN         NaN          NaN
# 50%     1.112088e+06           9.0        NaN         NaN          NaN
# 75%     1.187221e+06           9.0        NaN         NaN          NaN
# count   3.004780e+05      300478.0     300478      300478       300478
# first            NaN           NaN        NaN         NaN          NaN
# freq             NaN           NaN     300478       14242       103510
# last             NaN           NaN        NaN         NaN          NaN
# max     1.262500e+06           9.0        NaN         NaN          NaN
# ...

# %%
df["AnzahlFall"].plot(kind="density",y="Meldedatum", figsize=(15,7))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-b8102bfc2c7b> in <module>
# ----> 1 df["AnzahlFall"].plot(kind="density",y="Meldedatum", figsize=(15,7))
#
# NameError: name 'df' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.pie(np.array(dataset.groupby("Geschlecht").AnzahlFall.sum()), labels=("Men", "Women", "Unknown"), shadow="true", autopct="%d%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x2c60e995250>,
# ...
#  [Text(0.084722659114115, 1.0967324518918156, 'Men'),
#   Text(-0.10849488095474545, -1.094636405756092, 'Women'),
#   Text(1.0997411300284188, -0.02386308705546046, 'Unknown')],
#  [Text(0.04621235951679, 0.5982177010318993, '47%'),
#   Text(-0.05917902597531569, -0.5970744031396865, '51%'),
#   Text(0.5998587981973192, -0.013016229302978431, '0%')])

# %%
import seaborn as sns

# %%
sns.catplot(x="Bundesland",kind="count" , data=dataset)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-2d7fe6749342> in <module>
# ----> 1 sns.catplot(x="Bundesland",kind="count" , data=dataset)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3777     p = _CategoricalPlotter()
#    3778     p.require_numeric = plotter_class.require_numeric
# ...
